# %%
import pandas as pd

# %%
df = pd.read_csv("StudentsPerformance.csv")
df.head()
# Out:
#    Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0          65             86             67               78            2021
# 1          64             85             71               80            2019
# 2          76             77             77               84            2021
# 3          80             76             75               75            2021
# 4          63             91             62               90            2019

# %% [markdown]
# ## Math_Score ustunidan index sifatida foydalanib sortlansin.

# %%
math = df.set_index("Math_Score").sort_index()
math
# Out:
#             Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# Math_Score
# 62                     89             61               76            2019
# 62                     77             67               78            2021
# 63                     83             70               81            2019
# 63                     91             62               90            2019
# 64                     83             60               84            2021
# 64                     75             68               75            2021
# 64                     78             80               84            2019
# 64                     85             71               80            2019
# 65                     86             67               78            2021
# 66                     88             62               84            2018
# 68                     90             66               83            2019
# ...

# %% [markdown]
# ## Raqamli indexga qaytarilsin

# %%
math.reset_index()
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 0           62             89             61               76            2019
# 1           62             77             67               78            2021
# 2           63             83             70               81            2019
# 3           63             91             62               90            2019
# 4           64             83             60               84            2021
# 5           64             75             68               75            2021
# 6           64             78             80               84            2019
# 7           64             85             71               80            2019
# 8           65             86             67               78            2021
# 9           66             88             62               84            2018
# 10          68             90             66               83            2019
# ...

# %% [markdown]
# ## Writing_Scor ustuni 72 va 80 ga tenglar haqida ma'lumot chiqarilsin

# %%
df[df['Writing_Score'].isin([72, 80])]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 9           68             85             72               89            2019
# 10          64             78             80               84            2019
# 14          74             84             80               79            2019
# 23          75             75             80               89            2021

# %% [markdown]
# ## Loc orqali indexlar haqida ma'lumot olinsin

# %%
df.loc[[10, 29]]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 10          64             78             80               84            2019
# 29          72             82             61               95            2019

# %% [markdown]
# ## Biror ustunni set_index funksiyasi orqali indexga qo'yilsin.

# %%
wr = df.set_index(["Writing_Score", "Reading_Score"])
print(wr)
# Out:
#                              Math_Score  Placement_Score  Club_Join_Date
# Writing_Score Reading_Score
# 67            86                     65               78            2021
# 71            85                     64               80            2019
# 77            77                     76               84            2021
# 75            76                     80               75            2021
# 62            91                     63               90            2019
#               95                     73               79            2020
# 76            82                     72               79            2020
# 62            82                     77               87            2021
# 60            90                     74              100            2019
# 72            85                     68               89            2019
# 80            78                     64               84            2019
# ...

# %% [markdown]
# ## Loc dan foydalanib 10 dan 20 gacha ekementlarni chiqaring.

# %%
df.loc[10:20]
# Out:
#     Math_Score  Reading_Score  Writing_Score  Placement_Score  Club_Join_Date
# 10          64             78             80               84            2019
# 11          75             83             76               83            2019
# 12          62             89             61               76            2019
# 13          69             80             73               87            2021
# 14          74             84             80               79            2019
# 15          69             85             66               78            2019
# 16          64             75             68               75            2021
# 17          75             81             76               95            2019
# 18          73             80             73               75            2020
# 19          75             92             62               97            2020
# 20          69             82             60               93            2021
