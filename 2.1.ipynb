# %%
import pandas as pd

# %% [markdown]
# Biz pandas kutubxonasini chaqirib, o'zimizga qulay qilib pd deb belgilab oldik. Undan keyin ess quyida df deb data frame ochib olib, URL dagi jadvalni shu data framega o'qib, yuqoridagi 5ta qatorni chiqardik.

# %%
df = pd.read_csv("https://www.stats.govt.nz/assets/Uploads/Business-financial-data/Business-financial-data-March-2024-quarter/Download-data/wholesale-trade-survey-march-2024-quarter.zip")
df.head()
# Out:
#   Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 0      WTSQ.SFA1CA  1995.03     2368.69         NaN      F  Dollars
# 1      WTSQ.SFA1CA  1995.06     2100.44         NaN      F  Dollars
# 2      WTSQ.SFA1CA  1995.09     2070.21         NaN      F  Dollars
# 3      WTSQ.SFA1CA  1995.12     2284.77         NaN      F  Dollars
# 4      WTSQ.SFA1CA  1996.03     2134.76         NaN      F  Dollars
#
#    Magnitude                       Subject  \
# 0          6  Wholesale Trade Survey - WTS
# 1          6  Wholesale Trade Survey - WTS
# 2          6  Wholesale Trade Survey - WTS
# 3          6  Wholesale Trade Survey - WTS
# 4          6  Wholesale Trade Survey - WTS
#
#                                                Group  \
# 0  Industry by variable - (ANZSIC06) - Subannual ...
# 1  Industry by variable - (ANZSIC06) - Subannual ...
# 2  Industry by variable - (ANZSIC06) - Subannual ...
# 3  Industry by variable - (ANZSIC06) - Subannual ...
# ...

# %% [markdown]
# Endi esa pastda bu data frame haqida ma'lumot olamiz.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5372 entries, 0 to 5371
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  5372 non-null   object
#  1   Period            5372 non-null   float64
#  2   Data_value        5134 non-null   float64
#  3   Suppressed        0 non-null      float64
#  4   STATUS            5372 non-null   object
#  5   UNITS             5372 non-null   object
#  6   Magnitude         5372 non-null   int64
#  7   Subject           5372 non-null   object
#  8   Group             5372 non-null   object
#  9   Series_title_1    5372 non-null   object
#  10  Series_title_2    5372 non-null   object
#  11  Series_title_3    5372 non-null   object
#  12  Series_title_4    5372 non-null   object
#  13  Series_title_5    458 non-null    object
# dtypes: float64(3), int64(1), object(10)
# memory usage: 587.7+ KB

# %% [markdown]
# Yuqoridagi jadval hajmini ko'rib chiqaylik.

# %%
df.shape
# Out:
# (5372, 14)

# %%
df.describe()
# Out:
#             Period    Data_value  Suppressed    Magnitude
# count  5372.000000   5134.000000         0.0  5372.000000
# mean   2009.229136   3887.920610         NaN     5.488459
# std       8.430378   5385.914796         NaN     1.675737
# min    1995.030000    -27.800000         NaN     0.000000
# 25%    2002.060000    994.170000         NaN     6.000000
# 50%    2009.090000   2171.403000         NaN     6.000000
# 75%    2016.120000   4430.800750         NaN     6.000000
# max    2024.030000  41552.265000         NaN     6.000000

# %% [markdown]
# ## Yuqoridagi jadvalni matritsa ko'rinishiga keltirib ko'ramiz.

# %%
df.values
# Out:
# array([['WTSQ.SFA1CA', 1995.03, 2368.69, ..., 'Current prices',
#         'Unadjusted', nan],
#        ['WTSQ.SFA1CA', 1995.06, 2100.44, ..., 'Current prices',
#         'Unadjusted', nan],
#        ['WTSQ.SFA1CA', 1995.09, 2070.21, ..., 'Current prices',
#         'Unadjusted', nan],
#        ...,
#        ['WTSQ.SFZ9CT', 2023.09, nan, ..., 'Current prices', 'Trend', nan],
#        ['WTSQ.SFZ9CT', 2023.12, nan, ..., 'Current prices', 'Trend', nan],
#        ['WTSQ.SFZ9CT', 2024.03, nan, ..., 'Current prices', 'Trend', nan]],
#       dtype=object)

# %% [markdown]
# ## Ustun nomlarini ko'rib chiqsak

# %%
df.columns
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %% [markdown]
# ## Indexlar

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5372, step=1)

# %% [markdown]
# ## Data values bo'yicha so'rtlab ko'ramiz.

# %%
df.sort_values('Data_value')
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 4937    WTSQ.SFZ9CAAC  2003.03       -27.8         NaN      F  PERCENT
# 4936    WTSQ.SFZ9CAAC  2002.12       -23.0         NaN      F  PERCENT
# 4938    WTSQ.SFZ9CAAC  2003.06       -21.8         NaN      F  PERCENT
# 5168    WTSQ.SFZ9CSPC  2002.09       -16.1         NaN      R  PERCENT
# 4659    WTSQ.SFZ1CSPC  2020.06       -11.2         NaN      R  PERCENT
# ...               ...      ...         ...         ...    ...      ...
# 5367      WTSQ.SFZ9CT  2023.03         NaN         NaN      C  Dollars
# 5368      WTSQ.SFZ9CT  2023.06         NaN         NaN      C  Dollars
# 5369      WTSQ.SFZ9CT  2023.09         NaN         NaN      C  Dollars
# 5370      WTSQ.SFZ9CT  2023.12         NaN         NaN      C  Dollars
# 5371      WTSQ.SFZ9CT  2024.03         NaN         NaN      C  Dollars
#
#       Magnitude                       Subject  \
# 4937          0  Wholesale Trade Survey - WTS
# ...

# %%
df.sort_values("Data_value", ascending=False)
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 4323      WTSQ.SFZ1CA  2022.12   41552.265         NaN      F  Dollars
# 4327      WTSQ.SFZ1CA  2023.12   40443.441         NaN      F  Dollars
# 4553      WTSQ.SFZ1CS  2022.12   39082.893         NaN      R  Dollars
# 4322      WTSQ.SFZ1CA  2022.09   38903.207         NaN      F  Dollars
# 4554      WTSQ.SFZ1CS  2023.03   38810.022         NaN      R  Dollars
# ...               ...      ...         ...         ...    ...      ...
# 5367      WTSQ.SFZ9CT  2023.03         NaN         NaN      C  Dollars
# 5368      WTSQ.SFZ9CT  2023.06         NaN         NaN      C  Dollars
# 5369      WTSQ.SFZ9CT  2023.09         NaN         NaN      C  Dollars
# 5370      WTSQ.SFZ9CT  2023.12         NaN         NaN      C  Dollars
# 5371      WTSQ.SFZ9CT  2024.03         NaN         NaN      C  Dollars
#
#       Magnitude                       Subject  \
# 4323          6  Wholesale Trade Survey - WTS
# ...

# %% [markdown]
# ## Ikkita qiymat bo'yicha so'rtlaymiz.

# %%
df.sort_values(["Data_value", "Period"])
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 4937    WTSQ.SFZ9CAAC  2003.03       -27.8         NaN      F  PERCENT
# 4936    WTSQ.SFZ9CAAC  2002.12       -23.0         NaN      F  PERCENT
# 4938    WTSQ.SFZ9CAAC  2003.06       -21.8         NaN      F  PERCENT
# 5168    WTSQ.SFZ9CSPC  2002.09       -16.1         NaN      R  PERCENT
# 4659    WTSQ.SFZ1CSPC  2020.06       -11.2         NaN      R  PERCENT
# ...               ...      ...         ...         ...    ...      ...
# 3509      WTSQ.SFE9CT  2024.03         NaN         NaN      C  Dollars
# 3860      WTSQ.SFF1CT  2024.03         NaN         NaN      C  Dollars
# 4211      WTSQ.SFF9CT  2024.03         NaN         NaN      C  Dollars
# 4791      WTSQ.SFZ1CT  2024.03         NaN         NaN      C  Dollars
# 5371      WTSQ.SFZ9CT  2024.03         NaN         NaN      C  Dollars
#
#       Magnitude                       Subject  \
# 4937          0  Wholesale Trade Survey - WTS
# ...

# %%
df.sort_values(["Data_value", "Period"], ascending=[False, False])
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 4323      WTSQ.SFZ1CA  2022.12   41552.265         NaN      F  Dollars
# 4327      WTSQ.SFZ1CA  2023.12   40443.441         NaN      F  Dollars
# 4553      WTSQ.SFZ1CS  2022.12   39082.893         NaN      R  Dollars
# 4322      WTSQ.SFZ1CA  2022.09   38903.207         NaN      F  Dollars
# 4554      WTSQ.SFZ1CS  2023.03   38810.022         NaN      R  Dollars
# ...               ...      ...         ...         ...    ...      ...
# 3493      WTSQ.SFE9CT  2020.03         NaN         NaN      C  Dollars
# 3844      WTSQ.SFF1CT  2020.03         NaN         NaN      C  Dollars
# 4195      WTSQ.SFF9CT  2020.03         NaN         NaN      C  Dollars
# 4775      WTSQ.SFZ1CT  2020.03         NaN         NaN      C  Dollars
# 5355      WTSQ.SFZ9CT  2020.03         NaN         NaN      C  Dollars
#
#       Magnitude                       Subject  \
# 4323          6  Wholesale Trade Survey - WTS
# ...

# %% [markdown]
# ## Faqat bitta ustunni chiqaramiz

# %%
df["Data_value"].sort_values()
# Out:
# 4937   -27.8
# 4936   -23.0
# 4938   -21.8
# 5168   -16.1
# 4659   -11.2
#         ...
# 5367     NaN
# 5368     NaN
# 5369     NaN
# 5370     NaN
# 5371     NaN
# Name: Data_value, Length: 5372, dtype: float64

# %%
df["Data_value"].sort_values(ascending=False)
# Out:
# 4323    41552.265
# 4327    40443.441
# 4553    39082.893
# 4322    38903.207
# 4554    38810.022
#           ...
# 5367          NaN
# 5368          NaN
# 5369          NaN
# 5370          NaN
# 5371          NaN
# Name: Data_value, Length: 5372, dtype: float64

# %%
df["Series_title_4"] == "Trend"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5367     True
# 5368     True
# 5369     True
# 5370     True
# 5371     True
# Name: Series_title_4, Length: 5372, dtype: bool

# %%
df[df["Series_title_4"] == "Trend"]
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 234       WTSQ.SFA1CT  1995.03    2349.769         NaN      R  Dollars
# 235       WTSQ.SFA1CT  1995.06    2204.458         NaN      R  Dollars
# 236       WTSQ.SFA1CT  1995.09    2125.637         NaN      R  Dollars
# 237       WTSQ.SFA1CT  1995.12    2145.656         NaN      R  Dollars
# 238       WTSQ.SFA1CT  1996.03    2138.142         NaN      R  Dollars
# ...               ...      ...         ...         ...    ...      ...
# 5367      WTSQ.SFZ9CT  2023.03         NaN         NaN      C  Dollars
# 5368      WTSQ.SFZ9CT  2023.06         NaN         NaN      C  Dollars
# 5369      WTSQ.SFZ9CT  2023.09         NaN         NaN      C  Dollars
# 5370      WTSQ.SFZ9CT  2023.12         NaN         NaN      C  Dollars
# 5371      WTSQ.SFZ9CT  2024.03         NaN         NaN      C  Dollars
#
#       Magnitude                       Subject  \
# 234           6  Wholesale Trade Survey - WTS
# ...

# %%
s4 = df["Series_title_4"] == "Trend"
s3 = df["Series_title_2"] == "Sales (operating income)"
st = df["STATUS"] == "R"
df[(s3 & s4) & st]
# Out:
#      Series_reference   Period  Data_value  Suppressed STATUS    UNITS  \
# 234       WTSQ.SFA1CT  1995.03    2349.769         NaN      R  Dollars
# 235       WTSQ.SFA1CT  1995.06    2204.458         NaN      R  Dollars
# 236       WTSQ.SFA1CT  1995.09    2125.637         NaN      R  Dollars
# 237       WTSQ.SFA1CT  1995.12    2145.656         NaN      R  Dollars
# 238       WTSQ.SFA1CT  1996.03    2138.142         NaN      R  Dollars
# ...               ...      ...         ...         ...    ...      ...
# 4770      WTSQ.SFZ1CT  2018.12   27630.819         NaN      R  Dollars
# 4771      WTSQ.SFZ1CT  2019.03   27748.156         NaN      R  Dollars
# 4772      WTSQ.SFZ1CT  2019.06   27852.283         NaN      R  Dollars
# 4773      WTSQ.SFZ1CT  2019.09   27949.200         NaN      R  Dollars
# 4774      WTSQ.SFZ1CT  2019.12   28069.792         NaN      R  Dollars
#
#       Magnitude                       Subject  \
# 234           6  Wholesale Trade Survey - WTS
# ...
