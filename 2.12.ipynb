# %%
import seaborn as sns 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("medicare_data.csv")
df
# Out:
#         Rndrng_Prvdr_CCN                Rndrng_Prvdr_Org_Name  \
# 0                  10001      Southeast Health Medical Center
# 1                  10001      Southeast Health Medical Center
# 2                  10001      Southeast Health Medical Center
# 3                  10001      Southeast Health Medical Center
# 4                  10001      Southeast Health Medical Center
# ...                  ...                                  ...
# 145737            670300  Methodist Midlothian Medical Center
# 145738            670300  Methodist Midlothian Medical Center
# 145739            670309      Texas Health Hospital Mansfield
# 145740            670309      Texas Health Hospital Mansfield
# 145741            670309      Texas Health Hospital Mansfield
#
#        Rndrng_Prvdr_City         Rndrng_Prvdr_St  Rndrng_Prvdr_State_FIPS  \
# 0                 Dothan  1108 Ross Clark Circle                        1
# ...

# %%
plt.figure(figsize=(10, 6))
sns.countplot(y='Rndrng_Prvdr_CCN', data=df, order=df['Rndrng_Prvdr_CCN'].value_counts().index)
plt.title('Rendering Provider CCN Count')
plt.xlabel('Count')
plt.ylabel('Rendering Provider CCN')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Tot_Dschrgs'], kde=True)
plt.title('Total Discharges Distribution')
plt.xlabel('Total Discharges')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Avg_Mdcr_Pymt_Amt'], kde=True)
plt.title('Average Medicare Payment Amount Distribution')
plt.xlabel('Average Medicare Payment Amount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(y='Avg_Mdcr_Pymt_Amt', data=df)
plt.title('Boxplot of Average Medicare Payment Amount')
plt.xlabel('Average Medicare Payment Amount')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.scatterplot(x='Avg_Submtd_Cvrd_Chrg', y='Avg_Mdcr_Pymt_Amt', data=df)
plt.title('Scatterplot of Submitted Covered Charge vs. Medicare Payment Amount')
plt.xlabel('Average Submitted Covered Charge')
plt.ylabel('Average Medicare Payment Amount')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Avg_Tot_Pymt_Amt'], kde=True)
plt.title('Average Total Payment Amount Distribution')
plt.xlabel('Average Total Payment Amount')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Avg_Submtd_Cvrd_Chrg'], kde=True)
plt.title('Average Submitted Covered Charge Distribution')
plt.xlabel('Average Submitted Covered Charge')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Tot_Dschrgs'], kde=True)
plt.title('Total Discharges Distribution')
plt.xlabel('Total Discharges')
plt.ylabel('Frequency')
plt.show()

# %%
print(df.info())
print(df.describe())

# Noma'lum qiymatlarni tekshirish
print(df.isnull().sum())

# 1. Boxplot - Avg_Tot_Pymt_Amt bo'yicha
plt.figure(figsize=(10, 6))
sns.boxplot(y='Avg_Tot_Pymt_Amt', data=df)
plt.title('Boxplot of Average Total Payment Amount')
plt.xlabel('Average Total Payment Amount')
plt.show()

# 2. Violinplot - Avg_Tot_Pymt_Amt bo'yicha
plt.figure(figsize=(10, 6))
sns.violinplot(y='Avg_Tot_Pymt_Amt', data=df)
plt.title('Violinplot of Average Total Payment Amount')
plt.xlabel('Average Total Payment Amount')
plt.show()

# 3. Scatterplot - Avg_Tot_Pymt_Amt va Avg_Submtd_Cvrd_Chrg o'rtasida
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Avg_Submtd_Cvrd_Chrg', y='Avg_Tot_Pymt_Amt', data=df)
plt.title('Scatterplot of Submitted Covered Charge vs. Total Payment Amount')
plt.xlabel('Average Submitted Covered Charge')
plt.ylabel('Average Total Payment Amount')
plt.show()

# 4. Pairplot - Ba'zi ustunlar o'rtasidagi munosabatni ko'rsatish
sns.pairplot(df[['Tot_Dschrgs', 'Avg_Submtd_Cvrd_Chrg', 'Avg_Tot_Pymt_Amt', 'Avg_Mdcr_Pymt_Amt']])
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145742 entries, 0 to 145741
# Data columns (total 15 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   Rndrng_Prvdr_CCN           145742 non-null  int64
#  1   Rndrng_Prvdr_Org_Name      145742 non-null  object
#  2   Rndrng_Prvdr_City          145742 non-null  object
#  3   Rndrng_Prvdr_St            145742 non-null  object
#  4   Rndrng_Prvdr_State_FIPS    145742 non-null  int64
#  5   Rndrng_Prvdr_Zip5          145742 non-null  int64
#  6   Rndrng_Prvdr_State_Abrvtn  145742 non-null  object
#  7   Rndrng_Prvdr_RUCA          145065 non-null  float64
#  8   Rndrng_Prvdr_RUCA_Desc     145065 non-null  object
#  9   DRG_Cd                     145742 non-null  int64
#  10  DRG_Desc                   145742 non-null  object
#  11  Tot_Dschrgs                145742 non-null  int64
#  12  Avg_Submtd_Cvrd_Chrg       145742 non-null  float64
# ...

# %%
# Noma'lum qiymatlarni tekshirish
print(df.isnull().sum())

# 1. Boxplot - Avg_Submtd_Cvrd_Chrg bo'yicha
plt.figure(figsize=(10, 6))
sns.boxplot(y='Avg_Submtd_Cvrd_Chrg', data=df)
plt.title('Boxplot of Average Submitted Covered Charge')
plt.ylabel('Average Submitted Covered Charge')
plt.show()

# 2. Violinplot - Avg_Submtd_Cvrd_Chrg bo'yicha
plt.figure(figsize=(10, 6))
sns.violinplot(y='Avg_Submtd_Cvrd_Chrg', data=df)
plt.title('Violinplot of Average Submitted Covered Charge')
plt.ylabel('Average Submitted Covered Charge')
plt.show()

# 3. Scatterplot - Avg_Submtd_Cvrd_Chrg va Avg_Mdcr_Pymt_Amt o'rtasida
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Avg_Submtd_Cvrd_Chrg', y='Avg_Mdcr_Pymt_Amt', data=df)
plt.title('Scatterplot of Submitted Covered Charge vs. Medicare Payment Amount')
plt.xlabel('Average Submitted Covered Charge')
plt.ylabel('Average Medicare Payment Amount')
plt.show()

# 4. Pairplot - Ba'zi ustunlar o'rtasidagi munosabatni ko'rsatish
sns.pairplot(df[['Tot_Dschrgs', 'Avg_Submtd_Cvrd_Chrg', 'Avg_Tot_Pymt_Amt', 'Avg_Mdcr_Pymt_Amt']])
plt.show()
# Out:
# Rndrng_Prvdr_CCN               0
# Rndrng_Prvdr_Org_Name          0
# Rndrng_Prvdr_City              0
# Rndrng_Prvdr_St                0
# Rndrng_Prvdr_State_FIPS        0
# Rndrng_Prvdr_Zip5              0
# Rndrng_Prvdr_State_Abrvtn      0
# Rndrng_Prvdr_RUCA            677
# Rndrng_Prvdr_RUCA_Desc       677
# DRG_Cd                         0
# DRG_Desc                       0
# Tot_Dschrgs                    0
# Avg_Submtd_Cvrd_Chrg           0
# Avg_Tot_Pymt_Amt               0
# Avg_Mdcr_Pymt_Amt              0
# dtype: int64

# %%
# Noma'lum qiymatlarni tekshirish
print(df.isnull().sum())

# 1. Boxplot - Tot_Dschrgs bo'yicha
plt.figure(figsize=(10, 6))
sns.boxplot(y='Tot_Dschrgs', data=df)
plt.title('Boxplot of Total Discharges')
plt.ylabel('Total Discharges')
plt.show()

# 2. Violinplot - Tot_Dschrgs bo'yicha
plt.figure(figsize=(10, 6))
sns.violinplot(y='Tot_Dschrgs', data=df)
plt.title('Violinplot of Total Discharges')
plt.ylabel('Total Discharges')
plt.show()

# 3. Scatterplot - Tot_Dschrgs va Avg_Submtd_Cvrd_Chrg o'rtasida
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Tot_Dschrgs', y='Avg_Submtd_Cvrd_Chrg', data=df)
plt.title('Scatterplot of Total Discharges vs. Submitted Covered Charge')
plt.xlabel('Total Discharges')
plt.ylabel('Average Submitted Covered Charge')
plt.show()

# 4. Pairplot - Ba'zi ustunlar o'rtasidagi munosabatni ko'rsatish
sns.pairplot(df[['Tot_Dschrgs', 'Avg_Submtd_Cvrd_Chrg', 'Avg_Tot_Pymt_Amt', 'Avg_Mdcr_Pymt_Amt']])
plt.show()
# Out:
# Rndrng_Prvdr_CCN               0
# Rndrng_Prvdr_Org_Name          0
# Rndrng_Prvdr_City              0
# Rndrng_Prvdr_St                0
# Rndrng_Prvdr_State_FIPS        0
# Rndrng_Prvdr_Zip5              0
# Rndrng_Prvdr_State_Abrvtn      0
# Rndrng_Prvdr_RUCA            677
# Rndrng_Prvdr_RUCA_Desc       677
# DRG_Cd                         0
# DRG_Desc                       0
# Tot_Dschrgs                    0
# Avg_Submtd_Cvrd_Chrg           0
# Avg_Tot_Pymt_Amt               0
# Avg_Mdcr_Pymt_Amt              0
# dtype: int64
